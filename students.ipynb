# %% [markdown]
# ## Predicting student's marks
#
#
# We have used LinearRegressor and Support Vector Regressor for predictions

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('student-mat.csv', sep=';')

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Defining features and target data

# %%
X = data[['G1', 'G2', 'failures', 'absences', 'studytime']]
y = data['G3']

# %% [markdown]
# ### Splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# ### Applying Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = linreg.predict(X_test)

# %% [markdown]
# #### Analyzing the predictions

# %%
#from sklearn.metrics import classification_report, confusion_matrix

# %%
# Accuracy
acc = linreg.score(X_test, y_test)
acc
# Out:
# 0.7854018749344285

# %%
y_test.iloc[3]
# Out:
# 15

# %%
# printing the predictions with the used features

for i in range(len(y_pred)):
    print('Predicted Marks:', y_pred[i])
    print('Actual G3 Marks:', y_test.iloc[i],'\n')
# Out:
# Predicted Marks: 14.102200165793885
# Actual G3 Marks: 14
#
# Predicted Marks: 10.67419103523849
# Actual G3 Marks: 10
#
# Predicted Marks: 9.854309399312758
# Actual G3 Marks: 9
#
# Predicted Marks: 15.243138521142171
# Actual G3 Marks: 15
#
# Predicted Marks: 16.15556114704335
# Actual G3 Marks: 16
#
# Predicted Marks: 12.091224875347914
# Actual G3 Marks: 12
#
# Predicted Marks: 12.807172310379116
# Actual G3 Marks: 14
#
# Predicted Marks: 10.866854163537207
# Actual G3 Marks: 11
#
# Predicted Marks: 8.690250678879737
# Actual G3 Marks: 9
#
# Predicted Marks: 15.121132536447519
# Actual G3 Marks: 15
#
# Predicted Marks: 7.485042786356571
# Actual G3 Marks: 10
#
# Predicted Marks: 13.86733073118271
# Actual G3 Marks: 11
#
# Predicted Marks: 10.950286519999631
# Actual G3 Marks: 10
#
# Predicted Marks: 7.5929345330482985
# Actual G3 Marks: 8
#
# Predicted Marks: 15.065971632785658
# Actual G3 Marks: 15
#
# Predicted Marks: 14.107351253509716
# Actual G3 Marks: 14
#
# ...

# %% [markdown]
# ### Appliying Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='linear')

# %%
svr.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# prediction

svr_y_pred = svr.predict(X_test)

# %%
# Testing Accuracy

svr.score(X_test, svr_y_pred)
# Out:
# 1.0

# %%
# Accuracy in Training set

svr.score(X_train, y_train)
# Out:
# 0.8337591319637926

# %%
#X_test.iloc[0]

# %%
# printing the predictions with the used features

for i in range(len(svr_y_pred)):
    print('Predicted Marks:', svr_y_pred[i])
    print('Actual G3 Marks:', y_test.iloc[i])
    print('Other features were', X_test.iloc[i].to_list(),'\n')
# Out:
# Predicted Marks: 14.099960275872498
# Actual G3 Marks: 14
# Other features were [14, 14, 0, 4, 3]
#
# Predicted Marks: 11.099869970301377
# Actual G3 Marks: 10
# Other features were [11, 11, 0, 0, 3]
#
# Predicted Marks: 10.100038327078927
# Actual G3 Marks: 9
# Other features were [9, 10, 0, 9, 3]
#
# Predicted Marks: 15.099965956153945
# Actual G3 Marks: 15
# Other features were [16, 15, 0, 2, 2]
#
# Predicted Marks: 16.099911697147725
# Actual G3 Marks: 16
# Other features were [15, 16, 0, 2, 2]
#
# Predicted Marks: 12.100029757705279
# Actual G3 Marks: 12
# Other features were [13, 12, 0, 6, 3]
#
# Predicted Marks: 13.099865144134363
# Actual G3 Marks: 14
# Other features were [12, 13, 0, 0, 2]
#
# Predicted Marks: 11.099994534836704
# Actual G3 Marks: 11
# Other features were [10, 11, 0, 6, 2]
#
# Predicted Marks: 9.099991694696094
# Actual G3 Marks: 9
# Other features were [8, 9, 0, 5, 1]
#
# Predicted Marks: 15.099901300488348
# Actual G3 Marks: 15
# ...

# %% [markdown]
# ### Conclusion
# **We can say that SVR outplayed LinearRegressor**
